# %% [markdown]
# <h2>Load the data</h2>

# %%
import os
import re
import glob
import numpy as np
import pandas as pd
from nltk import tokenize

# %%
txt_files = []
for name in glob.glob('ElecDeb60To16/*.txt'):
    name = name.replace('\\','/')
    txt_files.append(name)

ann_files = []
for name in glob.glob('ElecDeb60To16/*.ann'):
    name = name.replace('\\','/')
    ann_files.append(name)

# %%
sent_all = []
ind_all = []

for file in txt_files:
    sent_list = []
    ind_list = []
    prev_ind = 0
    
    txt_file = open(file, encoding="utf8")
    text = txt_file.read()
    txt_file.close()
    
    
    with open(file, encoding="utf8") as infile:
        for line in infile:
            line = re.sub(r'(\([A-Z]+\)_[A-Z]+(\_[A-Z]+)?: )','',line)
            line = re.sub(r'([A-Z]+\_[A-Z]+\_[A-Z]+: )','',line)
            line = re.sub(r'([A-Z]+\_[A-Z]+: )','',line)
            line = re.sub(r'(\_[A-Z]+: )','',line)
            line = re.sub(r'([A-Z]+: )','',line)
            line = re.sub(r'\[[a-zA-Z0-9;,\s\"\'\.\S]*\]*','',line)
                  
            for sent in tokenize.sent_tokenize(line):  
                if not sent_list:
                    ind = text.find(sent,0,len(text)) 
                else:
                    ind = text.find(sent,prev_ind,len(text))
                prev_ind = ind
                sent_list.append([sent,ind])
                ind_list.append(ind)
                
    ind_all.append(np.array(ind_list))
    sent_all.append(sent_list)
#Up to this point we get a sent_all containing every debate (42 total) tokenized into sentences.
#sent_all = [sent_list, sent_list, sent_list,...]
#sent_list = [[sent1, index],[sent2, index],[sent3,index],...]
#ind_all = [ind_list, ind_list, ind_list,...]
#ind_list = [ind, ind, ind,...]

# %%
ann_all = []

for file in ann_files:
    ann_list = []
    
    with open(file, encoding="utf8") as infile:
        for line in infile:
            entry = line.split("\t")
            ann_list.append(entry)
    
    ann_all.append(ann_list)

# %%
#following part creates labels for task 1 (whether a sentence contains an argument component)

labels_arg_all = []

for i in range(len(ind_all)):
    labels_arg_arr = np.empty([len(ind_all[i]),2])
    sent_start_ind_list = []

    #column 0 of labels_arg are the starting indices of the senteces 
    for j in range(len(ind_all[i])):
        labels_arg_arr[j,0] = ind_all[i][j]
        
    #loop through each annotation entry, get the corresponding sentence starting index 
    for j in range(len(ann_all[i])):
        phrase_start = re.search(r'[0-9]+\s',ann_all[i][j][1]).group(0)
        sent_start_ind_list.append(ind_all[i][ind_all[i] <= int(phrase_start)].max())
        
        phrase_start = re.search(r';[0-9]+\s',ann_all[i][j][1])
        if phrase_start != None:
            phrase_start = phrase_start.group(0)[1:]
            ind2 = ind_all[i][ind_all[i] <= int(phrase_start)].max()
            if ind2 not in sent_start_ind_list:
                sent_start_ind_list.append(ind2)
    
    #loop through starting indices for sentences, check if each sentence contains an annotation (labeled as 1)
    for j in range(len(ind_all[i])):   
        if ind_all[i][j] in sent_start_ind_list:
            labels_arg_arr[j,1] = 1
        else:
            labels_arg_arr[j,1] = 0
    
    labels_arg_all.append(labels_arg_arr.astype(int))

#ann_all = [ann_list, ann_list, ann_list, ...]
#ann_list = [['T1', 'Claim/Premise xxx xxx', '...'], ['T2', 'Claim/Premise xxx xxx', '...'], 
    #['T3', 'Claim/Premise xxx xxx', '...'], ...]
#labels_arg_all = [labels_arg_arr, labels_arg_arr, labesl_arg_arr, ...]
#labels_arg_arr = np array of size (len(ind_list),2), no. of rows = no. of sentences in a txt file, 
    #col 0 = starting index of sentece, col 1 = label (1 for contain claim/premise, 0 for otherwise)

# %%
labels_cp_all = []

for i in range(len(labels_arg_all)):
    labels_cp_list = []
    
    for j in range(labels_arg_all[i].shape[0]):
        if labels_arg_all[i][j,1] != 0:
            labels_cp_list.append(labels_arg_all[i][j,0])
    
    labels_cp_arr = np.zeros((len(labels_cp_list),3))
    labels_cp_out = np.zeros((len(labels_cp_list),2))
    
    for k in range(len(labels_cp_list)):
        labels_cp_arr[k,0] = labels_cp_list[k]

        
    for j in range(len(ann_all[i])):
        #check for claim with only 1 continuous part
        phrase_start = re.search(r'c|Claim\s[0-9]+\s[0-9]+',ann_all[i][j][1])
        if phrase_start != None:
            phrase_start = phrase_start.group(0)
            labels_cp_arr[np.where(labels_cp_arr[:,0] == ind_all[i][ind_all[i] <= int(phrase_start.split()[1])].max())[0],1] +=\
            int(phrase_start.split()[2]) - int(phrase_start.split()[1])
        
        #check for claim formed from 2 separate parts
        phrase_start = re.search(r'c|Claim[0-9\s]+;[0-9]+\s[0-9]+',ann_all[i][j][1])
        if phrase_start != None:
            phrase_start = phrase_start.group(0)
            labels_cp_arr[np.where(labels_cp_arr[:,0] == ind_all[i][ind_all[i] <= int(phrase_start.split(';')[1].split()[0])].max())[0],1] +=\
            int(phrase_start.split(';')[1].split()[1]) - int(phrase_start.split(';')[1].split()[0])
        
        #check for premise with only 1 continuous part
        phrase_start = re.search(r'p|Premise\s[0-9]+\s[0-9]+',ann_all[i][j][1])
        if phrase_start != None:
            phrase_start = phrase_start.group(0)
            labels_cp_arr[np.where(labels_cp_arr[:,0] == ind_all[i][ind_all[i] <= int(phrase_start.split()[1])].max())[0],2] +=\
            int(phrase_start.split()[2]) - int(phrase_start.split()[1])
        
        #check for premise formed from 2 separate parts
        phrase_start = re.search(r'p|Premise[0-9\s]+;[0-9]+\s[0-9]+',ann_all[i][j][1])
        if phrase_start != None:
            phrase_start = phrase_start.group(0)
            labels_cp_arr[np.where(labels_cp_arr[:,0] == ind_all[i][ind_all[i] <= int(phrase_start.split(';')[1].split()[0])].max())[0],2] +=\
            int(phrase_start.split(';')[1].split()[1]) - int(phrase_start.split(';')[1].split()[0])
    
    #compare length of claim and premise components in a sentence, and label the sentence according to the longer component
    labels_cp_out[:,0] = labels_cp_arr[:,0]
    for m in range(labels_cp_arr.shape[0]):
        if labels_cp_arr[m,1] >= labels_cp_arr[m,2]:
            labels_cp_out[m,1] = 1
    
    labels_cp_all.append(labels_cp_out)
#labels_cp_all = [labels_cp_out, labels_cp_out, labels_cp_out, ...]
#labels_cp_out = np array of size ((len(labels_cp_list),3)), 
    #no. of rows = no. sentences that contains at least 1 claim or 1 premise,
    #col 0 = starting index of such a sentence, col 1 = label (1 for claim, 0 for premise)

# %%
ints = []
for lst in labels_cp_all:
    for char in lst:
        ints.append([int(char[0]), int(char[1])])

# %%
sentences = []
for lst in sent_all:
    for lsts in lst:
        sentences.append(lsts[0])

# %%
import csv
from itertools import zip_longest
indx = []
annotation = []
changed = []
# looping through labels and 
for i in labels_arg_all:
    for j in i:
        # if 0 - not annotated
        if j[1] == 0: 
            annotation.append([j[0], 'None'])
        # if 1 - annotated
        elif j[1] == 1:
            annotation.append([j[0], 'annotated'])
        indx.append(j[0])

# %%
claim_or_premise = {}
for char in ints:
    for num in indx:
        if int(char[0]) ==  num:
            claim_or_premise[char[0]] = char[1]
        else:
            continue

# %%
cp = {}
for k, v in claim_or_premise.items():
    if v == 0:
        cp[k] = 'Premise'
    elif v == 1:
        cp[k] = 'Claim'

# %%
dict_annotation = {}
dict_cp = {}
final = []
for i in annotation:
    dict_annotation[i[0]] = i[1]

# %%
print(dict_annotation)
# Out:
# {7: 'None', 21: 'None', 247: 'None', 284: 'None', 398: 'None', 599: 'None', 709: 'None', 879: 'None', 956: 'annotated', 978: 'None', 1098: 'annotated', 1375: 'annotated', 1538: 'annotated', 1717: 'annotated', 1870: 'annotated', 1929: 'annotated', 2037: 'None', 2183: 'None', 2308: 'None', 2340: 'annotated', 2438: 'None', 2472: 'None', 2693: 'annotated', 2837: 'annotated', 2986: 'annotated', 3061: 'annotated', 3201: 'annotated', 3351: 'None', 3626: 'annotated', 3843: 'annotated', 3948: 'annotated', 4067: 'annotated', 4128: 'annotated', 4246: 'annotated', 4354: 'annotated', 4671: 'None', 4790: 'annotated', 4868: 'annotated', 5051: 'annotated', 5126: 'annotated', 5230: 'annotated', 5331: 'annotated', 5357: 'annotated', 5414: 'None', 5494: 'annotated', 5510: 'annotated', 5565: 'annotated', 5619: 'annotated', 5672: 'None', 5772: 'None', 5894: 'None', 6143: 'None', 6394: 'None', 6477: 'annotated', 6566: 'annotated', 6616: 'annotated', 6648: 'annotated', 6783: 'None', 6827: 'None', 6894: 'annotated', 6970: 'None', 7094: 'annotated', 7156: 'annotated', 7191: 'annotated', 7427: 'annotated', 7471: 'annotated', 7586: 'annotated', 7647: 'annotated', 7749: 'annotated', 7768: 'annotated', 7835: 'annotated', 7890: 'annotated', 7963: 'None', 7991: 'None', 8059: 'annotated', 8236: 'annotated', 8413: 'annotated', 8488: 'None', 8560: 'annotated', 8698: 'None', 8727: 'annotated', 8928: 'annotated', 9078: 'None', 9114: 'annotated', 9152: 'None', 9193: 'annotated', 9314: 'annotated', 9337: 'annotated', 9546: 'annotated', 9583: 'annotated', 9717: 'annotated', 9878: 'annotated', 9923: 'None', 10062: 'annotated', 10211: 'None', 10231: 'annotated', 10389: 'None', 10421: 'annotated', 10558: 'None', 10581: 'annotated', 10675: 'annotated', 10705: 'None', 10758: 'annotated', 11093: 'annotated', 11182: 'annotated', 11255: 'None', 11281: 'annotated', 11412: 'None', 11443: 'annotated', 11577: 'None', 11608: 'None', 11743: 'annotated', 11776: 'None', 11838: 'None', 11879: 'None', 11907: 'annotated', 12016: 'annotated', 12087: 'None', 12152: 'None', 12220: 'annotated', 12324: 'annotated', 12420: 'None', 12592: 'None', 12626: 'annotated', 12836: 'None', 12997: 'None', 13091: 'annotated', 13128: 'None', 13184: 'None', 13211: 'annotated', 13312: 'annotated', 13654: 'None', 13819: 'None', 13975: 'None', 14025: 'None', 14214: 'None', 14262: 'annotated', 14414: 'None', 14472: 'None', 14484: 'None', 14610: 'None', 14673: 'annotated', 14806: 'annotated', 15054: 'None', 15239: 'None', 15321: 'annotated', 15354: 'annotated', 15409: 'annotated', 15588: 'annotated', 15610: 'annotated', 15785: 'annotated', 15962: 'None', 16027: 'annotated', 16123: 'annotated', 16165: 'None', 16265: 'annotated', 16371: 'annotated', 16505: 'annotated', 16623: 'None', 16829: 'annotated', 16874: 'annotated', 16898: 'None', 17132: 'annotated', 17187: 'annotated', 17222: 'None', 17329: 'annotated', 17392: 'None', 17418: 'None', 17457: 'None', 17671: 'annotated', 17821: 'annotated', 17905: 'annotated', 17962: 'annotated', 18052: 'annotated', 18276: 'annotated', 18555: 'None', 18847: 'annotated', 19108: 'None', 19235: 'annotated', 19443: 'annotated', 19661: 'annotated', 20009: 'annotated', 20174: 'annotated', 20391: 'annotated', 20631: 'annotated', 20672: 'annotated', 20944: 'None', 21006: 'annotated', 21110: 'None', 21134: 'annotated', 21247: 'annotated', 21408: 'annotated', 21505: 'annotated', 21607: 'None', 21658: 'annotated', 21825: 'annotated', 21883: 'annotated', 21924: 'annotated', 21996: 'annotated', 22079: 'annotated', 22280: 'annotated', 22373: 'annotated', 22497: 'annotated', 22585: 'annotated', 22645: 'annotated', 22799: 'None', 22866: 'annotated', 23000: 'annotated', 23151: 'None', 23282: 'None', 23324: 'annotated', 23428: 'annotated', 23483: 'annotated', 23833: 'None', 23873: 'annotated', 24033: 'annotated', 24092: 'annotated', 24212: 'annotated', 24342: 'None', 24369: 'annotated', 24499: 'annotated', 24790: 'annotated', 24827: 'annotated', 24913: 'None', 25023: 'annotated', 25174: 'an ...

# %%
final = {}
for k, v in dict_annotation.items():
    if k not in cp.keys():
        final[k] = v
    else:
        final[k] = v
for k, v in cp.items():
    if k not in final.keys():
        final[k] = v
    else:
        final[k] = [final[k], v] 
print(final)
# Out:
# {7: ['None', 'Claim'], 21: 'None', 247: 'None', 284: 'None', 398: 'None', 599: 'None', 709: 'None', 879: 'None', 956: ['annotated', 'Claim'], 978: 'None', 1098: ['annotated', 'Premise'], 1375: ['annotated', 'Claim'], 1538: ['annotated', 'Claim'], 1717: ['annotated', 'Premise'], 1870: ['annotated', 'Premise'], 1929: ['annotated', 'Premise'], 2037: ['None', 'Claim'], 2183: 'None', 2308: 'None', 2340: ['annotated', 'Claim'], 2438: 'None', 2472: 'None', 2693: ['annotated', 'Claim'], 2837: ['annotated', 'Claim'], 2986: ['annotated', 'Claim'], 3061: ['annotated', 'Claim'], 3201: ['annotated', 'Premise'], 3351: ['None', 'Premise'], 3626: ['annotated', 'Premise'], 3843: ['annotated', 'Claim'], 3948: ['annotated', 'Claim'], 4067: ['annotated', 'Claim'], 4128: ['annotated', 'Claim'], 4246: ['annotated', 'Claim'], 4354: ['annotated', 'Claim'], 4671: 'None', 4790: ['annotated', 'Claim'], 4868: ['annotated', 'Premise'], 5051: ['annotated', 'Premise'], 5126: ['annotated', 'Premise'], 5230: ['annotated', 'Premise'], 5331: ['annotated', 'Claim'], 5357: ['annotated', 'Claim'], 5414: 'None', 5494: ['annotated', 'Premise'], 5510: ['annotated', 'Claim'], 5565: ['annotated', 'Claim'], 5619: ['annotated', 'Claim'], 5672: 'None', 5772: 'None', 5894: 'None', 6143: 'None', 6394: ['None', 'Claim'], 6477: ['annotated', 'Claim'], 6566: ['annotated', 'Claim'], 6616: ['annotated', 'Claim'], 6648: ['annotated', 'Premise'], 6783: 'None', 6827: 'None', 6894: ['annotated', 'Claim'], 6970: 'None', 7094: ['annotated', 'Premise'], 7156: ['annotated', 'Claim'], 7191: ['annotated', 'Claim'], 7427: ['annotated', 'Claim'], 7471: ['annotated', 'Premise'], 7586: ['annotated', 'Claim'], 7647: ['annotated', 'Premise'], 7749: ['annotated', 'Claim'], 7768: ['annotated', 'Claim'], 7835: ['annotated', 'Claim'], 7890: ['annotated', 'Premise'], 7963: 'None', 7991: 'None', 8059: ['annotated', 'Claim'], 8236: ['annotated', 'Premise'], 8413: ['annotated', 'Premise'], 8488: 'None', 8560: ['annotated', 'Premise'], 8698: 'None', 8727: ['annotated', 'Claim'], 8928: ['annotated', 'Premise'], 9078: 'None', 9114: ['annotated', 'Claim'], 9152: ['None', 'Premise'], 9193: ['annotated', 'Claim'], 9314: ['annotated', 'Premise'], 9337: ['annotated', 'Claim'], 9546: ['annotated', 'Claim'], 9583: ['annotated', 'Premise'], 9717: ['annotated', 'Premise'], 9878: ['annotated', 'Premise'], 9923: 'None', 10062: ['annotated', 'Premise'], 10211: 'None', 10231: ['annotated', 'Claim'], 10389: 'None', 10421: ['annotated', 'Claim'], 10558: 'None', 10581: ['annotated', 'Claim'], 10675: ['annotated', 'Claim'], 10705: 'None', 10758: ['annotated', 'Premise'], 11093: ['annotated', 'Claim'], 11182: ['annotated', 'Premise'], 11255: 'None', 11281: ['annotated', 'Claim'], 11412: 'None', 11443: ['annotated', 'Claim'], 11577: 'None', 11608: ['None', 'Premise'], 11743: ['annotated', 'Claim'], 11776: 'None', 11838: 'None', 11879: 'None', 11907: ['annotated', 'Premise'], 12016: ['annotated', 'Claim'], 12087: 'None', 12152: 'None', 12220: ['annotated', 'Premise'], 12324: ['annotated', 'Premise'], 12420: 'None', 12592: 'None', 12626: ['annotated', 'Premise'], 12836: 'None', 12997: 'None', 13091: ['annotated', 'Premise'], 13128: ['None', 'Claim'], 13184: 'None', 13211: ['annotated', 'Claim'], 13312: ['annotated', 'Premise'], 13654: 'None', 13819: 'None', 13975: 'None', 14025: 'None', 14214: ['None', 'Premise'], 14262: ['annotated', 'Premise'], 14414: 'None', 14472: 'None', 14484: 'None', 14610: 'None', 14673: ['annotated', 'Claim'], 14806: ['annotated', 'Claim'], 15054: 'None', 15239: 'None', 15321: ['annotated', 'Claim'], 15354: ['annotated', 'Claim'], 15409: ['annotated', 'Premise'], 15588: ['annotated', 'Premise'], 15610: ['annotated', 'Claim'], 15785: ['annotated', 'Claim'], 15962: 'None', 16027: ['annotated', 'Claim'], 16123: ['annotated', 'Claim'], 16165: 'None', 16265: ['annotated', 'Premise'], 16371: ['annotated', 'Premise'], 16505: ['annotated', 'Claim'], 16623: ['None', 'Premise'], 16829: ['annotated', 'Premise'] ...

# %%
export_data = zip_longest(indx, sentences, changed, fillvalue = '')
with open('try.csv', 'w', encoding="UTF-8", newline='') as myfile:
      wr = csv.writer(myfile)
      wr.writerow(("Index", "Sentences", "Annotation"))
      wr.writerows(export_data)
myfile.close()

# %%
import pandas
df = pandas.read_csv('try.csv')
print(df)
